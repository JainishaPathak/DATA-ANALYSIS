# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
tech = pd.read_json('https://raw.githubusercontent.com/sahilrahman12/Technology-Lookup-Web-Application/main/technologies.json')
# cats = pd.read_json('https://raw.githubusercontent.com/AliasIO/wappalyzer/master/src/technologies.json')

# %%
data_tech = tech.copy()

# %%
data_tech.head()
# Out:
#                                                      1C-Bitrix  \
# cats                                                    [1, 6]
# description  1C-Bitrix is a system of web project managemen...
# headers      {'Set-Cookie': 'BITRIX_', 'X-Powered-CMS': 'Bi...
# html         (?:<link[^>]+components/bitrix|(?:src|href)="/...
# icon                                             1C-Bitrix.svg
#
#                                  3dCart @sulu/web          A-Frame  \
# cats                             [1, 6]      [59]             [25]
# description                         NaN       NaN              NaN
# headers      {'X-Powered-By': '3DCART'}       NaN              NaN
# html                                NaN       NaN  <a-scene[^<>]*>
# icon                         3dCart.png  Sulu.svg      A-Frame.svg
#
#                                                  A8.net  \
# cats                                               [71]
# description   A8.net is an affiliate marketing network.
# ...

# %%
#manipulate the data frame so that columns becomes the rows

# %%
data_tech = data_tech.T

# %%
data_tech.head()
# Out:
#              cats                                        description  \
# 1C-Bitrix  [1, 6]  1C-Bitrix is a system of web project managemen...
# 3dCart     [1, 6]                                                NaN
# @sulu/web    [59]                                                NaN
# A-Frame      [25]                                                NaN
# A8.net       [71]          A8.net is an affiliate marketing network.
#
#                                                      headers  \
# 1C-Bitrix  {'Set-Cookie': 'BITRIX_', 'X-Powered-CMS': 'Bi...
# 3dCart                            {'X-Powered-By': '3DCART'}
# @sulu/web                                                NaN
# A-Frame                                                  NaN
# A8.net                                                   NaN
#
#                                                         html           icon  \
# 1C-Bitrix  (?:<link[^>]+components/bitrix|(?:src|href)="/...  1C-Bitrix.svg
# ...

# %%
data_tech.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1511 entries, 1C-Bitrix to xtCommerce
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   cats         1511 non-null   object
#  1   description  776 non-null    object
#  2   headers      320 non-null    object
#  3   html         428 non-null    object
#  4   icon         1474 non-null   object
#  5   implies      482 non-null    object
#  6   scripts      679 non-null    object
#  7   website      1511 non-null   object
#  8   cookies      146 non-null    object
#  9   js           600 non-null    object
#  10  dom          60 non-null     object
#  11  pricing      213 non-null    object
#  12  saas         204 non-null    object
#  13  meta         272 non-null    object
#  14  cpe          195 non-null    object
#  15  certIssuer   5 non-null      object
#  16  url          51 non-null     object
#  17  oss          31 non-null     object
# ...

# %%
data_tech.shape
# Out:
# (1511, 21)

# %%
data_tech.columns
# Out:
# Index(['cats', 'description', 'headers', 'html', 'icon', 'implies', 'scripts',
#        'website', 'cookies', 'js', 'dom', 'pricing', 'saas', 'meta', 'cpe',
#        'certIssuer', 'url', 'oss', 'dns', 'excludes', 'css'],
#       dtype='object')

# %%
tec = data_tech.copy()

# %%
# for i in data_tech.cats
    # for j in range(len(i)):
    #   i[j] = cat.categories.iloc[(i[j]-1)]["name"]
# Out:
#   File "<ipython-input-35-d310454215f5>", line 3
#     #   i[j] = cat.categories.iloc[(i[j]-1)]["name"]
#                                                      ^
# SyntaxError: unexpected EOF while parsing

# %%
data_tech.cats
# Out:
# 1C-Bitrix     [1, 6]
# 3dCart        [1, 6]
# @sulu/web       [59]
# A-Frame         [25]
# A8.net          [71]
#                ...
# wisyCMS          [1]
# wpBakery        [51]
# wpCache         [23]
# xCharts         [25]
# xtCommerce       [6]
# Name: cats, Length: 1511, dtype: object

# %%
tec.description.isna().sum()
# Out:
# 735

# %%
tec.headers.notnull().sum()
# Out:
# 320

# %%
tec.headers
# Out:
# 1C-Bitrix     {'Set-Cookie': 'BITRIX_', 'X-Powered-CMS': 'Bi...
# 3dCart                               {'X-Powered-By': '3DCART'}
# @sulu/web                                                   NaN
# A-Frame                                                     NaN
# A8.net                                                      NaN
#                                     ...
# wisyCMS                                                     NaN
# wpBakery                                                    NaN
# wpCache       {'X-Powered-By': 'wpCache(?:/([\d.]+))?\;versi...
# xCharts                                                     NaN
# xtCommerce                                                  NaN
# Name: headers, Length: 1511, dtype: object

# %%
#find all the unique keys

# %%
for i in tec.headers:
  print(i)
# Out:
# {'Set-Cookie': 'BITRIX_', 'X-Powered-CMS': 'Bitrix Site Manager'}
# {'X-Powered-By': '3DCART'}
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# {'Server': 'AOLserver/?([\\d.]+)?\\;version:\\1'}
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# {'X-AH-Environment': '^\\w+$'}
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# {'X-Advertising-By': 'adnegah\\.net'}
# nan
# {'Cookie': 'CFTOKEN='}
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# {'X-Powered-By': '^E2 Aegea v(\\d+)$\\;version:\\1'}
# nan
# nan
# {'X-Powered-By': 'Afosto SaaS BV'}
# nan
# nan
# nan
# nan
# nan
# {'Server': '^Airee'}
# nan
# nan
# {'X-Akamai-Transformed': '', 'X-EdgeConnect-MidMile-RTT': '', 'X-EdgeConnect-Origin-MEX-Latency': ''}
# nan
# nan
# nan
# {'X-Akaunting': '^Free Accounting Software$'}
# {'Server': 'akka-http(?:/([\\d.]+))?\\;version:\\1'}
# nan
# nan
# {'Server': 'Allegro-Software-RomPager(?:/([\\d.]+))?\\;version:\\1'}
# nan
# nan
# ...

# %%
arr=[]
(list(tec.headers[0].keys()))
# Out:
# ['Set-Cookie', 'X-Powered-CMS']

# %%
l=[]
for i in data_tech.headers:
 if type (i)==dict:
  x=list(i.keys())
  for j in x:
    if j not in l:
     l.append(j)

l
# Out:
# ['Set-Cookie',
#  'X-Powered-CMS',
#  'X-Powered-By',
#  'Server',
#  'X-AH-Environment',
#  'X-Advertising-By',
#  'Cookie',
#  'X-Akamai-Transformed',
#  'X-EdgeConnect-MidMile-RTT',
#  'X-EdgeConnect-Origin-MEX-Latency',
#  'X-Akaunting',
#  'Via',
#  'X-Amz-Cf-Id',
#  'server',
#  'Arastta',
#  'X-Arastta',
#  'AR-PoweredBy',
#  'X-Confluence-Request-Time',
#  'X-StatusPage-Skip-Logging',
#  'X-StatusPage-Version',
#  'X-Hacker',
#  'azure-regionname',
#  'azure-sitename',
#  'azure-slotname',
#  'azure-version',
#  'X-EC-Debug',
#  'X-Supplied-By',
#  'X-Backdrop-Cache',
#  'X-Generator',
#  'CMS-Version',
#  'x-bubble-capacity-limit',
#  'x-bubble-capacity-used',
#  'x-bubble-perf',
#  'X-CF1',
#  'X-CF2',
#  'X-Plenty-Shop',
#  'Access-Control-Allow-Headers',
#  'Link',
#  'cf-cache-status',
#  'cf-ray',
#  'COMMERCE-SERVER-SOFTWARE',
#  'Derak-Umbrage',
#  'DNNOutputCache',
#  'X-Compressed-By',
#  'X-DataDome',
#  'X-DataDome-CID',
#  'X-Dotclear-Static-Cache',
# ...

# %%
len(l)
# Out:
# 185

# %%
arr = []
for i in range (len (tec.headers)):
 if not pd.isnull(tec.headers[i]):
  arr.extend(list (tec.headers[i].keys ()))

# %%
arr = set(arr)

# %%
len(arr)
# Out:
# 185

# %%
tec
# Out:
#               cats                                        description  \
# 1C-Bitrix   [1, 6]  1C-Bitrix is a system of web project managemen...
# 3dCart      [1, 6]                                                NaN
# @sulu/web     [59]                                                NaN
# A-Frame       [25]                                                NaN
# A8.net        [71]          A8.net is an affiliate marketing network.
# ...            ...                                                ...
# wisyCMS        [1]                                                NaN
# wpBakery      [51]  WPBakery is a drag and drop visual page builde...
# wpCache       [23]  WPCache is a static caching plugin for WordPress.
# xCharts       [25]                                                NaN
# xtCommerce     [6]                                                NaN
#
#                                                       headers  \
# 1C-Bitrix   {'Set-Cookie': 'BITRIX_', 'X-Powered-CMS': 'Bi...
# ...

# %%
url = "https://www.amazon.in/HP-Chromebook-11-6-inch-Touchscreen-11a-na0002MU/dp/B08WPNPTDD/ref=sr_1_1_sspa?crid=2AZLUG7I5W71C&keywords=laptop&qid=1674197412&sprefix=laptop%2Caps%2C538&sr=8-1-spons&sp_csd=d2lkZ2V0TmFtZT1zcF9hdGY&psc=1"

# %%
re.findall('[a-z]+',url)
# Out:
# ['https',
#  'www',
#  'amazon',
#  'in',
#  'hromebook',
#  'inch',
#  'ouchscreen',
#  'a',
#  'na',
#  'dp',
#  'ref',
#  'sr',
#  'sspa',
#  'crid',
#  'keywords',
#  'laptop',
#  'qid',
#  'sprefix',
#  'laptop',
#  'aps',
#  'sr',
#  'spons',
#  'sp',
#  'csd',
#  'd',
#  'lk',
#  'm',
#  't',
#  'zc',
#  'hd',
#  'psc']

# %%
regex= re.sub('.*//|/.*','',url)
if "www" in regex:
  regex= re.sub('www.','',regex)

# %%
print(regex)
# Out:
# amazon.in

# %%
regex= "https://"+re.sub('.*//|/.*|www\.','',url)
regex
# Out:
# 'https://amazon.in'

# %%
url = "https://en.wikipedia.org/wiki/Avengers:_Endgame"

# %%
regex= "https://"+re.sub('.*//|/.*|www\.','',url)
regex
# Out:
# 'https://en.wikipedia.org'

# %%
req = requests.get(regex)

# %%
req
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(req.content)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Wikipedia, the free encyclopedia</title>
# ...

# %%
tec
# Out:
#               cats                                        description  \
# 1C-Bitrix   [1, 6]  1C-Bitrix is a system of web project managemen...
# 3dCart      [1, 6]                                                NaN
# @sulu/web     [59]                                                NaN
# A-Frame       [25]                                                NaN
# A8.net        [71]          A8.net is an affiliate marketing network.
# ...            ...                                                ...
# wisyCMS        [1]                                                NaN
# wpBakery      [51]  WPBakery is a drag and drop visual page builde...
# wpCache       [23]  WPCache is a static caching plugin for WordPress.
# xCharts       [25]                                                NaN
# xtCommerce     [6]                                                NaN
#
#                                                       headers  \
# 1C-Bitrix   {'Set-Cookie': 'BITRIX_', 'X-Powered-CMS': 'Bi...
# ...

# %%
req.headers
# Out:
# {'date': 'Fri, 20 Jan 2023 06:53:03 GMT', 'server': 'mw1481.eqiad.wmnet', 'x-content-type-options': 'nosniff', 'content-language': 'en', 'vary': 'Accept-Encoding,Cookie,Authorization', 'last-modified': 'Fri, 20 Jan 2023 06:52:51 GMT', 'content-type': 'text/html; charset=UTF-8', 'content-encoding': 'gzip', 'age': '560', 'x-cache': 'cp1089 hit, cp1075 hit/390', 'x-cache-status': 'hit-front', 'server-timing': 'cache;desc="hit-front", host;desc="cp1075"', 'strict-transport-security': 'max-age=106384710; includeSubDomains; preload', 'report-to': '{ "group": "wm_nel", "max_age": 86400, "endpoints": [{ "url": "https://intake-logging.wikimedia.org/v1/events?stream=w3c.reportingapi.network_error&schema_uri=/w3c/reportingapi/network_error/1.0.0" }] }', 'nel': '{ "report_to": "wm_nel", "max_age": 86400, "failure_fraction": 0.05, "success_fraction": 0.0}', 'accept-ch': 'Sec-CH-UA-Arch,Sec-CH-UA-Bitness,Sec-CH-UA-Full-Version-List,Sec-CH-UA-Model,Sec-CH-UA-Platform-Version', 'permissions-policy':
# ...

# %%
req.cookies.get_dict().keys()
# Out:
# dict_keys([])
