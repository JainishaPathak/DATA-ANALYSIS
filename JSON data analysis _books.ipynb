# %% [markdown]
# JSON data analysis of books

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
df =pd.read_json("https://raw.githubusercontent.com/ozlerhakan/mongodb-json-files/master/datasets/books.json",lines=True)

# %%
df.head()
# Out:
#   _id                              title        isbn  pageCount  \
# 0   1                  Unlocking Android  1933988673        416
# 1   2  Android in Action, Second Edition  1935182722        592
# 2   3           Specification by Example  1617290084          0
# 3   4                   Flex 3 in Action  1933988746        576
# 4   5                   Flex 4 in Action  1935182420        600
#
#                                publishedDate  \
# 0  {'$date': '2009-04-01T00:00:00.000-0700'}
# 1  {'$date': '2011-01-14T00:00:00.000-0800'}
# 2  {'$date': '2011-06-03T00:00:00.000-0700'}
# 3  {'$date': '2009-02-02T00:00:00.000-0800'}
# 4  {'$date': '2010-11-15T00:00:00.000-0800'}
#
#                                         thumbnailUrl  \
# 0  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 1  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 2  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 3  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# ...

# %%
df.columns
# Out:
# Index(['_id', 'title', 'isbn', 'pageCount', 'publishedDate', 'thumbnailUrl',
#        'shortDescription', 'longDescription', 'status', 'authors',
#        'categories'],
#       dtype='object')

# %%
df.shape[1]
# Out:
# 11

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 431 entries, 0 to 430
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   _id               431 non-null    object
#  1   title             431 non-null    object
#  2   isbn              428 non-null    object
#  3   pageCount         431 non-null    int64
#  4   publishedDate     353 non-null    object
#  5   thumbnailUrl      411 non-null    object
#  6   shortDescription  160 non-null    object
#  7   longDescription   263 non-null    object
#  8   status            431 non-null    object
#  9   authors           431 non-null    object
#  10  categories        431 non-null    object
# dtypes: int64(1), object(10)
# memory usage: 37.2+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 431 entries, 0 to 430
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   _id               431 non-null    object
#  1   title             431 non-null    object
#  2   isbn              428 non-null    object
#  3   pageCount         431 non-null    int64
#  4   publishedDate     353 non-null    object
#  5   thumbnailUrl      411 non-null    object
#  6   shortDescription  160 non-null    object
#  7   longDescription   263 non-null    object
#  8   status            431 non-null    object
#  9   authors           431 non-null    object
#  10  categories        431 non-null    object
# dtypes: int64(1), object(10)
# memory usage: 37.2+ KB

# %%
df.describe()
# Out:
#          pageCount
# count   431.000000
# mean    289.259861
# std     260.873349
# min       0.000000
# 25%       0.000000
# 50%     350.000000
# 75%     475.000000
# max    1101.000000

# %%
df.tail()
# Out:
#                                       _id  \
# 426  {'$oid': '53c2ae8528d75d572c06adb8'}
# 427  {'$oid': '53c2ae8528d75d572c06adb9'}
# 428  {'$oid': '53c2ae8528d75d572c06adba'}
# 429  {'$oid': '53c2ae8528d75d572c06adbb'}
# 430  {'$oid': '53c2ae8528d75d572c06adbc'}
#
#                                          title           isbn  pageCount  \
# 426                             DSLs in Action     1935182455        376
# 427  Database Programming for Handheld Devices     1884777856          0
# 428           Jakarta Commons Online Bookshelf     1932394524        402
# 429                   Browsing with HttpClient  1932394524a-e          0
# 430               Codec: Encoders and Decoders  1932394524j-e          0
#
#                                  publishedDate  \
# 426  {'$date': '2010-12-01T00:00:00.000-0800'}
# 427  {'$date': '2000-07-01T00:00:00.000-0700'}
# 428  {'$date': '2005-03-01T00:00:00.000-0800'}
# 429  {'$date': '2005-03-01T00:00:00.000-0800'}
# ...

# %%
df.isnull().sum()
# Out:
# _id                   0
# title                 0
# isbn                  3
# pageCount             0
# publishedDate        78
# thumbnailUrl         20
# shortDescription    271
# longDescription     168
# status                0
# authors               0
# categories            0
# dtype: int64

# %%
df[df.isbn.isnull()]
# Out:
#      _id                                          title isbn  pageCount  \
# 21    23          Hibernate in Action (Chinese Edition)  NaN        400
# 98   148                    Portlets and Apache Portals  NaN        500
# 358  707  Secrets of the JavaScript Ninja pBook upgrade  NaN          0
#
#                                  publishedDate  \
# 21   {'$date': '1999-06-01T00:00:00.000-0700'}
# 98   {'$date': '2005-10-01T00:00:00.000-0700'}
# 358                                        NaN
#
#                                           thumbnailUrl  \
# 21   https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 98   https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 358                                                NaN
#
#                                       shortDescription  \
# 21                                                 NaN
# 98   Portlets and Apache Portals was not published ...
# 358                                                NaN
#
# ...

# %%
df.drop('isbn',axis=1,inplace=True)

# %%
df
# Out:
#                                       _id  \
# 0                                       1
# 1                                       2
# 2                                       3
# 3                                       4
# 4                                       5
# ..                                    ...
# 426  {'$oid': '53c2ae8528d75d572c06adb8'}
# 427  {'$oid': '53c2ae8528d75d572c06adb9'}
# 428  {'$oid': '53c2ae8528d75d572c06adba'}
# 429  {'$oid': '53c2ae8528d75d572c06adbb'}
# 430  {'$oid': '53c2ae8528d75d572c06adbc'}
#
#                                          title  pageCount  \
# 0                            Unlocking Android        416
# 1            Android in Action, Second Edition        592
# 2                     Specification by Example          0
# 3                             Flex 3 in Action        576
# 4                             Flex 4 in Action        600
# ..                                         ...        ...
# ...

# %%
df.tail()
# Out:
#                                       _id  \
# 426  {'$oid': '53c2ae8528d75d572c06adb8'}
# 427  {'$oid': '53c2ae8528d75d572c06adb9'}
# 428  {'$oid': '53c2ae8528d75d572c06adba'}
# 429  {'$oid': '53c2ae8528d75d572c06adbb'}
# 430  {'$oid': '53c2ae8528d75d572c06adbc'}
#
#                                          title  pageCount  \
# 426                             DSLs in Action        376
# 427  Database Programming for Handheld Devices          0
# 428           Jakarta Commons Online Bookshelf        402
# 429                   Browsing with HttpClient          0
# 430               Codec: Encoders and Decoders          0
#
#                                  publishedDate  \
# 426  {'$date': '2010-12-01T00:00:00.000-0800'}
# 427  {'$date': '2000-07-01T00:00:00.000-0700'}
# 428  {'$date': '2005-03-01T00:00:00.000-0800'}
# 429  {'$date': '2005-03-01T00:00:00.000-0800'}
# 430  {'$date': '2005-03-01T00:00:00.000-0800'}
#
#                                           thumbnailUrl  \
# ...

# %%
len(df.title.unique())
# Out:
# 427

# %%
#show the duplicated rows wrt the title

# %%
df[df.duplicated('title')]
# Out:
#      _id                                   title  pageCount  \
# 113  165                     Android in Practice          0
# 175  231               SQL Server MVP Deep Dives        848
# 176  232               SQL Server MVP Deep Dives        848
# 325  656  Jaguar Development with PowerBuilder 7          0
#
#                                  publishedDate  \
# 113                                        NaN
# 175  {'$date': '2009-11-15T00:00:00.000-0800'}
# 176  {'$date': '2009-11-01T00:00:00.000-0700'}
# 325  {'$date': '1999-08-09T00:00:00.000-0700'}
#
#                                           thumbnailUrl  \
# 113  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 175  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 176  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 325                                                NaN
#
#                                       shortDescription  \
# 113                                                NaN
# ...

# %%
df[df['title']=="Jaguar Development with PowerBuilder 7"]
# Out:
#      _id                                   title  pageCount  \
# 17    19  Jaguar Development with PowerBuilder 7        550
# 325  656  Jaguar Development with PowerBuilder 7          0
#
#                                  publishedDate  \
# 17   {'$date': '1999-08-01T00:00:00.000-0700'}
# 325  {'$date': '1999-08-09T00:00:00.000-0700'}
#
#                                           thumbnailUrl  \
# 17   https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 325                                                NaN
#
#                                       shortDescription  \
# 17   Jaguar Development with PowerBuilder 7 is the ...
# 325                                                NaN
#
#                                        longDescription   status  \
# 17   Jaguar Development with PowerBuilder 7 is the ...  PUBLISH
# 325                                                NaN  PUBLISH
#
#                 authors                     categories
# ...

# %%
df[df['title']=="SQL Server MVP Deep Dives"]
# Out:
#      _id                      title  pageCount  \
# 174  230  SQL Server MVP Deep Dives        848
# 175  231  SQL Server MVP Deep Dives        848
# 176  232  SQL Server MVP Deep Dives        848
#
#                                  publishedDate  \
# 174  {'$date': '2009-11-01T00:00:00.000-0700'}
# 175  {'$date': '2009-11-15T00:00:00.000-0800'}
# 176  {'$date': '2009-11-01T00:00:00.000-0700'}
#
#                                           thumbnailUrl  \
# 174  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 175  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 176  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
#
#                                       shortDescription  \
# 174  SQL Server MVP Deep Dives is organized into fi...
# 175  SQL Server MVP Deep Dives is organized into fi...
# 176                                                NaN
#
#                                        longDescription   status  \
# ...

# %%
df[df.title.duplicated()]
# Out:
#      _id                                   title  pageCount  \
# 113  165                     Android in Practice          0
# 175  231               SQL Server MVP Deep Dives        848
# 176  232               SQL Server MVP Deep Dives        848
# 325  656  Jaguar Development with PowerBuilder 7          0
#
#                                  publishedDate  \
# 113                                        NaN
# 175  {'$date': '2009-11-15T00:00:00.000-0800'}
# 176  {'$date': '2009-11-01T00:00:00.000-0700'}
# 325  {'$date': '1999-08-09T00:00:00.000-0700'}
#
#                                           thumbnailUrl  \
# 113  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 175  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 176  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 325                                                NaN
#
#                                       shortDescription  \
# 113                                                NaN
# ...

# %%
df.drop_duplicates('title',inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 427 entries, 0 to 430
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   _id               427 non-null    object
#  1   title             427 non-null    object
#  2   isbn              424 non-null    object
#  3   pageCount         427 non-null    int64
#  4   publishedDate     350 non-null    object
#  5   thumbnailUrl      408 non-null    object
#  6   shortDescription  159 non-null    object
#  7   longDescription   262 non-null    object
#  8   status            427 non-null    object
#  9   authors           427 non-null    object
#  10  categories        427 non-null    object
# dtypes: int64(1), object(10)
# memory usage: 40.0+ KB

# %%
df['_id']=np.arange(1,428)

# %%
df._id
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 426    423
# 427    424
# 428    425
# 429    426
# 430    427
# Name: _id, Length: 427, dtype: int64

# %%
df=df.reset_index(drop=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 427 entries, 0 to 426
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   _id               427 non-null    int64
#  1   title             427 non-null    object
#  2   isbn              424 non-null    object
#  3   pageCount         427 non-null    int64
#  4   publishedDate     350 non-null    object
#  5   thumbnailUrl      408 non-null    object
#  6   shortDescription  159 non-null    object
#  7   longDescription   262 non-null    object
#  8   status            427 non-null    object
#  9   authors           427 non-null    object
#  10  categories        427 non-null    object
# dtypes: int64(2), object(9)
# memory usage: 36.8+ KB

# %%
df [ 'pageCount'].fillna(df.pageCount.mean  , inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 424 entries, 0 to 423
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   _id               421 non-null    float64
#  1   title             420 non-null    object
#  2   pageCount         424 non-null    object
#  3   publishedDate     343 non-null    object
#  4   thumbnailUrl      401 non-null    object
#  5   shortDescription  155 non-null    object
#  6   longDescription   258 non-null    object
#  7   status            420 non-null    object
#  8   authors           420 non-null    object
#  9   categories        420 non-null    object
# dtypes: float64(1), object(9)
# memory usage: 36.4+ KB

# %%
df [ 'pageCount'] = df['pageCount'].fillna(df.pageCount.mean)

# %%
df [ 'pageCount']
# Out:
# 0      416
# 1      592
# 2        0
# 3      576
# 4      600
#       ...
# 426    376
# 427      0
# 428    402
# 429      0
# 430      0
# Name: pageCount, Length: 431, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 431 entries, 0 to 430
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   _id               431 non-null    object
#  1   title             431 non-null    object
#  2   isbn              428 non-null    object
#  3   pageCount         431 non-null    int64
#  4   publishedDate     353 non-null    object
#  5   thumbnailUrl      411 non-null    object
#  6   shortDescription  160 non-null    object
#  7   longDescription   263 non-null    object
#  8   status            431 non-null    object
#  9   authors           431 non-null    object
#  10  categories        431 non-null    object
# dtypes: int64(1), object(10)
# memory usage: 37.2+ KB

# %%
mean = round(np.mean(df.pageCount))
df [ 'pageCount']=df [ 'pageCount'].replace(0, mean)

# %%
df.pageCount
# Out:
# 0      416
# 1      592
# 2      289
# 3      576
# 4      600
#       ...
# 422    376
# 423    289
# 424    402
# 425    289
# 426    289
# Name: pageCount, Length: 427, dtype: int64

# %%
df.head(10)
# Out:
#    _id                              title        isbn  pageCount  \
# 0    1                  Unlocking Android  1933988673        416
# 1    2  Android in Action, Second Edition  1935182722        592
# 2    3           Specification by Example  1617290084        289
# 3    4                   Flex 3 in Action  1933988746        576
# 4    5                   Flex 4 in Action  1935182420        600
# 5    6  Collective Intelligence in Action  1933988312        425
# 6    7           Zend Framework in Action  1933988320        432
# 7    8                       Flex on Java  1933988797        265
# 8    9                  Griffon in Action  1935182234        375
# 9   10                      OSGi in Depth  193518217X        325
#
#                                publishedDate  \
# 0  {'$date': '2009-04-01T00:00:00.000-0700'}
# 1  {'$date': '2011-01-14T00:00:00.000-0800'}
# 2  {'$date': '2011-06-03T00:00:00.000-0700'}
# 3  {'$date': '2009-02-02T00:00:00.000-0800'}
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 427 entries, 0 to 426
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   _id               427 non-null    int64
#  1   title             427 non-null    object
#  2   isbn              424 non-null    object
#  3   pageCount         427 non-null    int64
#  4   publishedDate     350 non-null    object
#  5   thumbnailUrl      408 non-null    object
#  6   shortDescription  159 non-null    object
#  7   longDescription   262 non-null    object
#  8   status            427 non-null    object
#  9   authors           427 non-null    object
#  10  categories        427 non-null    object
# dtypes: int64(2), object(9)
# memory usage: 36.8+ KB

# %%
data =df.copy()

# %%
data.head()
# Out:
#    _id                              title        isbn  pageCount  \
# 0    1                  Unlocking Android  1933988673        416
# 1    2  Android in Action, Second Edition  1935182722        592
# 2    3           Specification by Example  1617290084        289
# 3    4                   Flex 3 in Action  1933988746        576
# 4    5                   Flex 4 in Action  1935182420        600
#
#                                publishedDate  \
# 0  {'$date': '2009-04-01T00:00:00.000-0700'}
# 1  {'$date': '2011-01-14T00:00:00.000-0800'}
# 2  {'$date': '2011-06-03T00:00:00.000-0700'}
# 3  {'$date': '2009-02-02T00:00:00.000-0800'}
# 4  {'$date': '2010-11-15T00:00:00.000-0800'}
#
#                                         thumbnailUrl  \
# 0  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 1  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 2  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 3  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# ...

# %%
for i in range (len (data.publishedDate)):
  data.publishedDate [i] = re.sub("^{.*: '|-.*}","",str(df['publishedDate'][i]))
# Out:
# <ipython-input-114-ca5086e28c68>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.publishedDate [i] = re.sub("^{.*: '|-.*}","",str(df['publishedDate'][i]))

# %%
data.head()
# Out:
#    _id                              title        isbn  pageCount  \
# 0    1                  Unlocking Android  1933988673        416
# 1    2  Android in Action, Second Edition  1935182722        592
# 2    3           Specification by Example  1617290084        289
# 3    4                   Flex 3 in Action  1933988746        576
# 4    5                   Flex 4 in Action  1935182420        600
#
#   publishedDate                                       thumbnailUrl  \
# 0          2009  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 1          2011  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 2          2011  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 3          2009  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 4          2010  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
#
#                                     shortDescription  \
# 0  Unlocking Android: A Developer's Guide provide...
# 1  Android in Action, Second Edition is a compreh...
# ...

# %%
url="https://raw.githubusercontent.com/ozlerhakan/mongodb-json-files/master/datasets/books.json"
req=requests.get(url)

# %%
#df [df.publishedDate.isna()]
data.loc[[96]]
# Out:
#     _id                        title        isbn  pageCount publishedDate  \
# 96   97  Distributed Agile in Action  1935182412        325             0
#
#                                          thumbnailUrl  \
# 96  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
#
#                                      shortDescription  \
# 96  Distributed Agile in Action is the first book ...
#
#                                       longDescription status  \
# 96  As organizations try to do more with less, dev...   MEAP
#
#                                  authors              categories
# 96  [Vikas Hazrati, Balaji D Loganathan]  [Software Engineering]

# %%
data.publishedDate.fillna("0",inplace=True)

# %%
data.publishedDate.loc[[96]]
# Out:
# 96    nan
# Name: publishedDate, dtype: object

# %%
data.publishedDate = data.publishedDate.replace('nan','0')

# %%
data.publishedDate.loc[[96]]
# Out:
# 96    0
# Name: publishedDate, dtype: object

# %%
data.info()

# %%
data.publishedDate = data.publishedDate.astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 427 entries, 0 to 426
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   _id               427 non-null    int64
#  1   title             427 non-null    object
#  2   isbn              424 non-null    object
#  3   pageCount         427 non-null    int64
#  4   publishedDate     427 non-null    int64
#  5   thumbnailUrl      408 non-null    object
#  6   shortDescription  159 non-null    object
#  7   longDescription   262 non-null    object
#  8   status            427 non-null    object
#  9   authors           427 non-null    object
#  10  categories        427 non-null    object
# dtypes: int64(3), object(8)
# memory usage: 36.8+ KB

# %%
mean = round(np.mean(data.publishedDate))
data['publishedDate']=data[ 'publishedDate'].replace(0,mean)

# %%
data.publishedDate.loc[[96]]
# Out:
# 96    1645
# Name: publishedDate, dtype: int64

# %%
data.drop(['thumbnailUrl', 'shortDescription', 'longDescription'],axis = 1,inplace=True)

# %%
data
# Out:
#      _id                                      title           isbn  pageCount  \
# 0      1                          Unlocking Android     1933988673        416
# 1      2          Android in Action, Second Edition     1935182722        592
# 2      3                   Specification by Example     1617290084        289
# 3      4                           Flex 3 in Action     1933988746        576
# 4      5                           Flex 4 in Action     1935182420        600
# ..   ...                                        ...            ...        ...
# 422  423                             DSLs in Action     1935182455        376
# 423  424  Database Programming for Handheld Devices     1884777856        289
# 424  425           Jakarta Commons Online Bookshelf     1932394524        402
# 425  426                   Browsing with HttpClient  1932394524a-e        289
# 426  427               Codec: Encoders and Decoders  1932394524j-e        289
#
#      publishedDate   status  \
# ...

# %%
data.status.unique()
# Out:
# array(['PUBLISH', 'MEAP'], dtype=object)

# %%
data[data['status']=="PUBLISH"].sum()
# Out:
# <ipython-input-142-5bed1e2c4a25>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data[data['status']=="PUBLISH"].sum()
# _id                                                          68326
# title            Unlocking AndroidAndroid in Action, Second Edi...
# pageCount                                                   150389
# publishedDate                                               718727
# status           PUBLISHPUBLISHPUBLISHPUBLISHPUBLISHPUBLISHPUBL...
# authors          [W. Frank Ableson, Charlie Collins, Robi Sen, ...
# categories       [Open Source, Mobile, Java, Software Engineeri...
# dtype: object

# %%
data['status'].value_counts()
# Out:
# PUBLISH    360
# MEAP        67
# Name: status, dtype: int64

# %%
#MEAP TO UNPUBLISHED
data['status']=data['status'].replace('MEAP','UNPUBLISHED')

# %%
data.authors
# Out:
# 0          [W. Frank Ableson, Charlie Collins, Robi Sen]
# 1                           [W. Frank Ableson, Robi Sen]
# 2                                          [Gojko Adzic]
# 3            [Tariq Ahmed with Jon Hirschi, Faisal Abid]
# 4      [Tariq Ahmed, Dan Orlando, John C. Bland II, J...
#                              ...
# 422                                                   []
# 423                                                   []
# 424                                                   []
# 425                                                   []
# 426                                                   []
# Name: authors, Length: 427, dtype: object

# %%
data.drop(['_id', 'authors'],axis  = 1,inplace  = True)

# %%
#clearn the colum categories

# %%
data.drop(['categories'],axis  = 1,inplace  = True)

# %%
data
# Out:
#                                          title           isbn  pageCount  \
# 0                            Unlocking Android     1933988673        416
# 1            Android in Action, Second Edition     1935182722        592
# 2                     Specification by Example     1617290084        289
# 3                             Flex 3 in Action     1933988746        576
# 4                             Flex 4 in Action     1935182420        600
# ..                                         ...            ...        ...
# 422                             DSLs in Action     1935182455        376
# 423  Database Programming for Handheld Devices     1884777856        289
# 424           Jakarta Commons Online Bookshelf     1932394524        402
# 425                   Browsing with HttpClient  1932394524a-e        289
# 426               Codec: Encoders and Decoders  1932394524j-e        289
#
#      publishedDate   status
# 0             2009  PUBLISH
# 1             2011  PUBLISH
# ...

# %%
#data analysis

# %%
data['status'].value_counts().plot.bar(figsize=(20,10))
plt.grid()

# %%
x=data[ 'publishedDate'].value_counts()
plt.hist(x,bins=5)
# Out:
# (array([13.,  7.,  1.,  0.,  1.]),
#  array([ 1. , 16.2, 31.4, 46.6, 61.8, 77. ]),
#  <a list of 5 Patch objects>)

# %%
data.sort_values('pageCount',ascending=False).head(10)
# Out:
#                                                  title        isbn  pageCount  \
# 60   Essential Guide to Peoplesoft Development and ...  1884777929       1101
# 251                      Ten Years of UserFriendly.Org  1935182129       1096
# 68                             Java Foundation Classes  1884777678       1088
# 397                            Windows Forms in Action  1932394656        950
# 189                            Silverlight 5 in Action  1617290319        925
# 211                               Swing Second Edition  193011088X        912
# 408                Dynamic WAP Application Development  1930110081        888
# 22                     Java Persistence with Hibernate  1932394885        880
# 102           Java Network Programming, Second Edition  188477749X        860
# 173                          SQL Server MVP Deep Dives  1935182048        848
#
#      publishedDate   status
# 60            2000  PUBLISH
# 251           2008  PUBLISH
# ...

# %%
x = data.title.head (10)
y=data.pageCount.head (10)
plt.bar(x,y)
# Out:
# <BarContainer object of 10 artists>
